# %% [markdown]
# <a href="https://colab.research.google.com/github/ms236566/-/blob/main/%D0%9B%D0%B0%D0%B1%D1%80%D0%B0%D0%B1_02_pandas_%D0%9C%D0%BE%D1%81%D0%BA%D0%B2%D0%B8%D1%87%D0%B5%D0%B2%D0%B0%D0%9E%D0%92_%D0%94%D0%9F%D0%9823_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Pandas

# %% [markdown]
# Материалы:
# * Макрушин С.В. "Лекция 2: Библиотека Pandas"
# * https://pandas.pydata.org/docs/user_guide/index.html#
# * https://pandas.pydata.org/docs/reference/index.html
# * Уэс Маккини. Python и анализ данных

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## Задачи для совместного разбора

# %% [markdown]
# 1. Загрузите данные из файла `sp500hst.txt` и обозначьте столбцы в соответствии с содержимым: `"date", "ticker", "open", "high", "low", "close", "volume"`.

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('/content/drive/MyDrive/L2/sp500hst.txt',
                 names=['date', 'ticker', 'open', 'high', 'low', 'close', 'volume'],
                 parse_dates=['date'] )
df
# Out:
#              date ticker   open     high     low  close  volume
# 0      2009-08-21      A  25.60  25.6100  25.220  25.55   34758
# 1      2009-08-24      A  25.64  25.7400  25.330  25.50   22247
# 2      2009-08-25      A  25.50  25.7000  25.225  25.34   30891
# 3      2009-08-26      A  25.32  25.6425  25.145  25.48   33334
# 4      2009-08-27      A  25.50  25.5700  25.230  25.54   70176
# ...           ...    ...    ...      ...     ...    ...     ...
# 122569 2010-08-13    ZMH  51.72  51.9000  51.380  51.44   14561
# 122570 2010-08-16    ZMH  51.13  51.4700  50.600  51.00   13489
# 122571 2010-08-17    ZMH  51.14  51.6000  50.890  51.21   20498
# 122572 2010-08-19    ZMH  51.63  51.6300  50.170  50.22   18259
# 122573 2010-08-20    ZMH  50.03  50.5500  49.480  49.82   17792
#
# [122574 rows x 7 columns]

# %% [markdown]
# 2. Рассчитайте среднее значение показателей для каждого из столбцов c номерами 3-6.

# %%
# вариант решения 1
print('среднее значение для столбца "high": '+str(df.high.mean()))
print('среднее значение для столбца "low": '+str(df.low.mean()))
print('среднее значение для столбца "close": '+str(df.close.mean()))
print('среднее значение для столбца "volume": '+str(df.volume.mean()))
# Out:
# среднее значение для столбца "high": 43.102243387667855
# среднее значение для столбца "low": 42.05446366521448
# среднее значение для столбца "close": 42.60186484817335
# среднее значение для столбца "volume": 81395.06813843067

# %%
# вариант решения 2
print('среднее значение для столбца "high": '+str(df.iloc [:, 3].mean()))
print('среднее значение для столбца "low": '+str(df.iloc [:, 4].mean()))
print('среднее значение для столбца "close": '+str(df.iloc [:, 5].mean()))
print('среднее значение для столбца "volume": '+str(df.iloc [:, 6].mean()))
# Out:
# среднее значение для столбца "high": 43.102243387667855
# среднее значение для столбца "low": 42.05446366521448
# среднее значение для столбца "close": 42.60186484817335
# среднее значение для столбца "volume": 81395.06813843067

# %% [markdown]
# 3. Добавьте столбец, содержащий только число месяца, к которому относится дата.

# %%
df.assign(month=df.date.dt.month)
# Out:
#              date ticker   open     high     low  close  volume  month
# 0      2009-08-21      A  25.60  25.6100  25.220  25.55   34758      8
# 1      2009-08-24      A  25.64  25.7400  25.330  25.50   22247      8
# 2      2009-08-25      A  25.50  25.7000  25.225  25.34   30891      8
# 3      2009-08-26      A  25.32  25.6425  25.145  25.48   33334      8
# 4      2009-08-27      A  25.50  25.5700  25.230  25.54   70176      8
# ...           ...    ...    ...      ...     ...    ...     ...    ...
# 122569 2010-08-13    ZMH  51.72  51.9000  51.380  51.44   14561      8
# 122570 2010-08-16    ZMH  51.13  51.4700  50.600  51.00   13489      8
# 122571 2010-08-17    ZMH  51.14  51.6000  50.890  51.21   20498      8
# 122572 2010-08-19    ZMH  51.63  51.6300  50.170  50.22   18259      8
# 122573 2010-08-20    ZMH  50.03  50.5500  49.480  49.82   17792      8
#
# [122574 rows x 8 columns]

# %% [markdown]
# 4. Рассчитайте суммарный объем торгов для для одинаковых значений тикеров.

# %%
df.groupby('ticker').volume.sum()
# Out:
# ticker
# A        8609336
# AA      81898998
# AAPL    52261170
# ABC      9006756
# ABT     18975870
#           ...
# XTO     21297931
# YHOO    56837171
# YUM     10971538
# ZION    15551119
# ZMH      4938916
# Name: volume, Length: 524, dtype: int64

# %% [markdown]
# 5. Загрузите данные из файла sp500hst.txt и обозначьте столбцы в соответствии с содержимым: "date", "ticker", "open", "high", "low", "close", "volume". Добавьте столбец с расшифровкой названия тикера, используя данные из файла `sp_data2.csv` . В случае нехватки данных об именах тикеров корректно обработать их.

# %%
ticker_names = pd.read_csv(
    '/content/drive/MyDrive/L2/sp_data2.csv',
    names=['ticker', 'name'],
    usecols=[0,1],
    sep=';',
    index_col=0
)

df.join(ticker_names, on='ticker', validate='m:1').fillna('no data')
# Out:
#              date ticker   open     high     low  close  volume  \
# 0      2009-08-21      A  25.60  25.6100  25.220  25.55   34758
# 1      2009-08-24      A  25.64  25.7400  25.330  25.50   22247
# 2      2009-08-25      A  25.50  25.7000  25.225  25.34   30891
# 3      2009-08-26      A  25.32  25.6425  25.145  25.48   33334
# 4      2009-08-27      A  25.50  25.5700  25.230  25.54   70176
# ...           ...    ...    ...      ...     ...    ...     ...
# 122569 2010-08-13    ZMH  51.72  51.9000  51.380  51.44   14561
# 122570 2010-08-16    ZMH  51.13  51.4700  50.600  51.00   13489
# 122571 2010-08-17    ZMH  51.14  51.6000  50.890  51.21   20498
# 122572 2010-08-19    ZMH  51.63  51.6300  50.170  50.22   18259
# 122573 2010-08-20    ZMH  50.03  50.5500  49.480  49.82   17792
#
#                         name
# 0       Agilent Technologies
# 1       Agilent Technologies
# 2       Agilent Technologies
# 3       Agilent Technologies
# 4       Agilent Technologies
# ...

# %% [markdown]
# ## Лабораторная работа №2

# %% [markdown]
# ### Базовые операции с `DataFrame`

# %% [markdown]
# 1.1 В файлах `recipes_sample.csv` и `reviews_sample.csv` находится информация об рецептах блюд и отзывах на эти рецепты соответственно. Загрузите данные из файлов в виде `pd.DataFrame` с названиями `recipes` и `reviews`. Обратите внимание на корректное считывание столбца с индексами в таблице `reviews` (безымянный столбец).

# %%
recipes = pd.read_csv('/content/drive/MyDrive/L2/recipes_sample.csv', delimiter=',')
reviews = pd.read_csv('/content/drive/MyDrive/L2/reviews_sample.csv', delimiter=',', index_col=0)
reviews
# Out:
#             user_id  recipe_id        date  rating  \
# 370476        21752      57993  2003-05-01       5
# 624300       431813     142201  2007-09-16       5
# 187037       400708     252013  2008-01-10       4
# 706134   2001852463     404716  2017-12-11       5
# 312179        95810     129396  2008-03-14       5
# ...             ...        ...         ...     ...
# 1013457     1270706     335534  2009-05-17       4
# 158736      2282344       8701  2012-06-03       0
# 1059834      689540     222001  2008-04-08       5
# 453285   2000242659     354979  2015-06-02       5
# 691207       463435     415599  2010-09-30       5
#
#                                                     review
# 370476   Last week whole sides of frozen salmon fillet ...
# 624300   So simple and so tasty!  I used a yellow capsi...
# 187037   Very nice breakfast HH, easy to make and yummy...
# 706134   These are a favorite for the holidays and so e...
# ...

# %%
recipes
# Out:
#                                                name      id  minutes  \
# 0             george s at the cove  black bean soup   44123       90
# 1                healthy for them  yogurt popsicles   67664       10
# 2                      i can t believe it s spinach   38798       30
# 3                              italian  gut busters   35173       45
# 4          love is in the air  beef fondue   sauces   84797       25
# ...                                             ...     ...      ...
# 29995  zurie s holey rustic olive and cheddar bread  267661       80
# 29996          zwetschgenkuchen  bavarian plum cake  386977      240
# 29997   zwiebelkuchen   southwest german onion cake  103312       75
# 29998                                   zydeco soup  486161       60
# 29999        cookies by design   cookies on a stick  298512       29
#
#        contributor_id   submitted  n_steps  \
# 0               35193  2002-10-25      NaN
# 1               91970  2003-07-26      NaN
# ...

# %% [markdown]
# 1.2 Для каждой из таблиц выведите основные параметры:
# * количество точек данных (строк);
# * количество столбцов;
# * тип данных каждого столбца.

# %%
pd.DataFrame(
    [[recipes.shape[0], recipes.shape[1], recipes.dtypes],
    [reviews.shape[0], reviews.shape[1], reviews.dtypes]],
    columns=['rows', 'columns', 'dtype'],
    index=['recipes', 'reviews'])
# Out:
#            rows  columns                                              dtype
# recipes   30000        8  name               object
# id                  ...
# reviews  126696        5  user_id       int64
# recipe_id     int64
# date  ...

# %% [markdown]
# 1.3 Исследуйте, в каких столбцах таблиц содержатся пропуски. Посчитайте долю строк, содержащих пропуски, в отношении к общему количеству строк.

# %%
print('recipes\n')
print((recipes.isna()*1)[recipes.columns].sum()/len(recipes))
#Метод DataFrame.isna() ищет None или numpy.NaN/NA в DataFrame;
print('\nreviews\n')
print((reviews.isna()*1)[reviews.columns].sum()/len(reviews))
# Out:
# recipes
#
# name              0.000000
# id                0.000000
# minutes           0.000000
# contributor_id    0.000000
# submitted         0.000000
# n_steps           0.373000
# description       0.020767
# n_ingredients     0.296000
# dtype: float64
#
# reviews
#
# user_id      0.000000
# recipe_id    0.000000
# date         0.000000
# rating       0.000000
# review       0.000134
# dtype: float64

# %% [markdown]
# 1.4 Рассчитайте среднее значение для каждого из числовых столбцов (где это имеет смысл).

# %%
print('средняя оценка: '+str(reviews.rating.mean()))
print('среднее количество минут: '+str(recipes.minutes.mean()))
print('среднее количество шагов: '+str(recipes.n_steps.mean()))
print('среднее количество ингредиентов: '+str(recipes.n_ingredients.mean()))
# Out:
# средняя оценка: 4.410802235271832
# среднее количество минут: 123.35813333333333
# среднее количество шагов: 9.805582137161085
# среднее количество ингредиентов: 9.008285984848484

# %% [markdown]
# 1.5 Создайте серию из 10 случайных названий рецептов.

# %%
recipes.name[np.random.choice(len(recipes), 10, replace = False)]
# Out:
# 1979                  baked shrimp in chipotle sauce
# 22436            rendez vous chilies rellenos quiche
# 18308                                   mushroom pie
# 25072                 spaghetti with bacon and onion
# 24197                           simple baked chicken
# 21464                                potato ham hash
# 9794                 easy and delicious clam chowder
# 16828          man on the moon cake with lunar icing
# 2517     bea s buffalo chicken and blue cheese pizza
# 14859                           jamaican stewed fish
# Name: name, dtype: object

# %% [markdown]
# 1.6 Измените индекс в таблице `reviews`, пронумеровав строки, начиная с нуля.

# %%
reviews.reset_index(inplace=True, drop=True)
#сбрасывают индекс или его уровень и использует вместо него индекс по умолчанию
#drop = True - индекс НЕ вставляется в качестве столбца
#inplace=True - следует ли изменять фрейм данных вместо создания нового
reviews
# Out:
#            user_id  recipe_id        date  rating  \
# 0            21752      57993  2003-05-01       5
# 1           431813     142201  2007-09-16       5
# 2           400708     252013  2008-01-10       4
# 3       2001852463     404716  2017-12-11       5
# 4            95810     129396  2008-03-14       5
# ...            ...        ...         ...     ...
# 126691     1270706     335534  2009-05-17       4
# 126692     2282344       8701  2012-06-03       0
# 126693      689540     222001  2008-04-08       5
# 126694  2000242659     354979  2015-06-02       5
# 126695      463435     415599  2010-09-30       5
#
#                                                    review
# 0       Last week whole sides of frozen salmon fillet ...
# 1       So simple and so tasty!  I used a yellow capsi...
# 2       Very nice breakfast HH, easy to make and yummy...
# 3       These are a favorite for the holidays and so e...
# 4       Excellent soup!  The tomato flavor is just gre...
# ...

# %% [markdown]
# 1.7 Выведите информацию о рецептах, время выполнения которых не больше 20 минут и кол-во ингредиентов в которых не больше 5.

# %%
recipes[(recipes.minutes <= 20) & (recipes.n_ingredients <= 5)]
# Out:
#                                                     name      id  minutes  \
# 28                                   quick biscuit bread  302399       20
# 60                         peas  fit for a king or queen  303944       20
# 90                     hawaiian sunrise           mimosa  100837        5
# 91            tasty dish s   banana pudding in 2 minutes  286484        2
# 94                                    1 minute meatballs   11361       13
# ...                                                  ...     ...      ...
# 29873  zip and steam red potatoes with butter and garlic  304922       13
# 29874                          ziplock vanilla ice cream   74250       10
# 29905                      zucchini and corn with cheese  256177       15
# 29980               zucchini with jalapeno monterey jack  320622       10
# 29983                          zucchini with serrano ham  162411       15
#
#        contributor_id   submitted  n_steps  \
# ...

# %% [markdown]
# ### Работа с датами в `pandas`

# %% [markdown]
# 2.1 Преобразуйте столбец `submitted` из таблицы `recipes` в формат времени. Модифицируйте решение задачи 1.1 так, чтобы считать столбец сразу в нужном формате.

# %%
recipes.submitted = pd.to_datetime(recipes.submitted, format='%Y/%m/%d')
print(recipes.submitted)
# Out:
# 0       2002-10-25
# 1       2003-07-26
# 2       2002-08-29
# 3       2002-07-27
# 4       2004-02-23
#            ...
# 29995   2007-11-25
# 29996   2009-08-24
# 29997   2004-11-03
# 29998   2012-08-29
# 29999   2008-04-15
# Name: submitted, Length: 30000, dtype: datetime64[ns]

# %%
recipes1 = pd.read_csv('/content/drive/MyDrive/L2/recipes_sample.csv', delimiter=',', parse_dates=['submitted'], dayfirst=True)
reviews1 = pd.read_csv('/content/drive/MyDrive/L2/reviews_sample.csv', delimiter=',', parse_dates=['date'], dayfirst=True, index_col=0)
recipes1.submitted = pd.to_datetime(recipes1.submitted, format='%Y/%m/%d')
reviews1.date = pd.to_datetime(reviews1.date, format='%Y/%m/%d')
pd.DataFrame([[recipes1.dtypes], [reviews1.dtypes]], columns=['dtype'], index=['recipes1', 'reviews1'])
# Out:
#                                                       dtype
# recipes1  name                      object
# id           ...
# reviews1  user_id               int64
# recipe_id         ...

# %% [markdown]
# 2.2 Выведите информацию о рецептах, добавленных в датасет не позже 2010 года.

# %%
recipes1[recipes1.submitted.dt.year < 2010]
recipes1 = recipes1[['submitted'] + [x for x in recipes1.columns if x != 'submitted']]
recipes1
# Out:
#        submitted                                          name      id  \
# 0     2002-10-25         george s at the cove  black bean soup   44123
# 1     2003-07-26            healthy for them  yogurt popsicles   67664
# 2     2002-08-29                  i can t believe it s spinach   38798
# 3     2002-07-27                          italian  gut busters   35173
# 4     2004-02-23      love is in the air  beef fondue   sauces   84797
# ...          ...                                           ...     ...
# 29995 2007-11-25  zurie s holey rustic olive and cheddar bread  267661
# 29996 2009-08-24          zwetschgenkuchen  bavarian plum cake  386977
# 29997 2004-11-03   zwiebelkuchen   southwest german onion cake  103312
# 29998 2012-08-29                                   zydeco soup  486161
# 29999 2008-04-15        cookies by design   cookies on a stick  298512
#
#        minutes  contributor_id  n_steps  \
# 0           90           35193      NaN
# ...

# %% [markdown]
# ### Работа со строковыми данными в `pandas`

# %% [markdown]
# 3.1  Добавьте в таблицу `recipes` столбец `description_length`, в котором хранится длина описания рецепта из столбца `description`.

# %%
recipes1['description_length'] = recipes.description.str.len()
dl_id = recipes1['description_length']
recipes1.drop(labels=['description_length'], axis=1,inplace = True)
recipes1.insert(2, 'description_length', dl_id)
recipes1
# Out:
#        submitted                                          name  \
# 0     2002-10-25         george s at the cove  black bean soup
# 1     2003-07-26            healthy for them  yogurt popsicles
# 2     2002-08-29                  i can t believe it s spinach
# 3     2002-07-27                          italian  gut busters
# 4     2004-02-23      love is in the air  beef fondue   sauces
# ...          ...                                           ...
# 29995 2007-11-25  zurie s holey rustic olive and cheddar bread
# 29996 2009-08-24          zwetschgenkuchen  bavarian plum cake
# 29997 2004-11-03   zwiebelkuchen   southwest german onion cake
# 29998 2012-08-29                                   zydeco soup
# 29999 2008-04-15        cookies by design   cookies on a stick
#
#        description_length      id  minutes  contributor_id  n_steps  \
# 0                   330.0   44123       90           35193      NaN
# 1                   255.0   67664       10           91970      NaN
# ...

# %% [markdown]
# 3.2 Измените название каждого рецепта в таблице `recipes` таким образом, чтобы каждое слово в названии начиналось с прописной буквы.

# %%
recipes1.name = recipes1.name.str.title()
print(recipes1.name)
# Out:
# 0               George S At The Cove  Black Bean Soup
# 1                  Healthy For Them  Yogurt Popsicles
# 2                        I Can T Believe It S Spinach
# 3                                Italian  Gut Busters
# 4            Love Is In The Air  Beef Fondue   Sauces
#                              ...
# 29995    Zurie S Holey Rustic Olive And Cheddar Bread
# 29996            Zwetschgenkuchen  Bavarian Plum Cake
# 29997     Zwiebelkuchen   Southwest German Onion Cake
# 29998                                     Zydeco Soup
# 29999          Cookies By Design   Cookies On A Stick
# Name: name, Length: 30000, dtype: object

# %% [markdown]
# 3.3 Добавьте в таблицу `recipes` столбец `name_word_count`, в котором хранится количество слов из названии рецепта (считайте, что слова в названии разделяются только пробелами). Обратите внимание, что между словами может располагаться несколько пробелов подряд.

# %%
recipes1['name_word_count'] = recipes1.name.str.strip(' ').str.split().str.len()
print(recipes1.name_word_count.where)
# Out:
# <bound method Series.where of 0        8
# 1        5
# 2        7
# 3        3
# 4        8
#         ..
# 29995    8
# 29996    4
# 29997    5
# 29998    2
# 29999    7
# Name: name_word_count, Length: 30000, dtype: int64>

# %% [markdown]
# ### Группировки таблиц `pd.DataFrame`

# %% [markdown]
# 4.1 Посчитайте количество рецептов, представленных каждым из участников (`contributor_id`). Какой участник добавил максимальное кол-во рецептов?

# %%
recipes1.groupby('contributor_id').count()
x = recipes1.contributor_id.max(axis=0)
print('Участник: ', x)
recipes1.sort_values('contributor_id', ascending=False).head(1)
# Out:
# Участник:  2002247884
#        submitted                name  description_length      id  minutes  \
# 15938 2018-08-15  Lemon Pom Pom Cake               302.0  536747      210
#
#        contributor_id  n_steps  \
# 15938      2002247884     51.0
#
#                                              description  n_ingredients  \
# 15938  by far one of my most joyous cake creations, t...           20.0
#
#        name_word_count
# 15938                4

# %% [markdown]
# 4.2 Посчитайте средний рейтинг к каждому из рецептов. Для скольких рецептов отсутствуют отзывы? Обратите внимание, что отзыв с нулевым рейтингом или не заполненным текстовым описанием не считается отсутствующим.

# %%
print(reviews.groupby('rating').mean())
# Out:
#              user_id      recipe_id
# rating
# 0       5.487131e+08  172269.223218
# 1       5.907147e+08  164335.092077
# 2       2.760024e+08  149268.285627
# 3       1.454038e+08  148574.318447
# 4       9.026489e+07  157076.479057
# 5       1.124181e+08  160589.139655

# %% [markdown]
# 4.3 Посчитайте количество рецептов с разбивкой по годам создания.

# %%
df6 = recipes1.sort_values('submitted', axis=0).drop_duplicates()
df6.value_counts('submitted')
# Out:
# submitted
# 2002-03-28    60
# 2005-04-12    58
# 2008-01-03    50
# 2006-06-17    47
# 2008-01-22    46
#               ..
# 2011-11-25     1
# 2011-11-26     1
# 2011-11-29     1
# 2011-11-30     1
# 2018-08-15     1
# Length: 4032, dtype: int64

# %% [markdown]
# ### Объединение таблиц `pd.DataFrame`

# %% [markdown]
# 5.1 При помощи объединения таблиц, создайте `DataFrame`, состоящий из четырех столбцов: `id`, `name`, `user_id`, `rating`. Рецепты, на которые не оставлен ни один отзыв, должны отсутствовать в полученной таблице. Подтвердите правильность работы вашего кода, выбрав рецепт, не имеющий отзывов, и попытавшись найти строку, соответствующую этому рецепту, в полученном `DataFrame`.

# %%
dfA = recipes[['name', 'id']]
dfB = reviews[['user_id','rating',]]
dfC = pd.merge(dfA, dfB, left_on='id', right_on='rating', how='outer')
dfC
# Out:
#                                             name       id    user_id  rating
# 0          george s at the cove  black bean soup  44123.0        NaN     NaN
# 1             healthy for them  yogurt popsicles  67664.0        NaN     NaN
# 2                   i can t believe it s spinach  38798.0        NaN     NaN
# 3                           italian  gut busters  35173.0        NaN     NaN
# 4       love is in the air  beef fondue   sauces  84797.0        NaN     NaN
# ...                                          ...      ...        ...     ...
# 156691                                       NaN      NaN   178427.0     2.0
# 156692                                       NaN      NaN  1059677.0     2.0
# 156693                                       NaN      NaN   440299.0     2.0
# 156694                                       NaN      NaN   477308.0     2.0
# 156695                                       NaN      NaN  1207345.0     2.0
#
# [156696 rows x 4 columns]

# %%
dfD1 = recipes1[['name', 'id']]
dfD2 = reviews1[['user_id','rating','recipe_id']]
dfD3 = pd.merge(dfD1, dfD2, how='right', left_on='id', right_on='recipe_id')
'''dfD3.dropna()
dfD3.drop('recipe_id', axis=1, inplace=True)'''
dfD3
# Out:
#                                                      name      id     user_id  \
# 0                                    Salmon With Tomatoes   57993       21752
# 1                                    Lemon Cajun Stir Fry  142201      431813
# 2             Cottage Cheese  Honey And Cinnamon On Toast  252013      400708
# 3                                           Belly Buttons  404716  2001852463
# 4                                      Double Tomato Soup  129396       95810
# ...                                                   ...     ...         ...
# 126691                     Melissa S Lemon Pepper Chicken  335534     1270706
# 126692                    Should Be Illegal Oven Bbq Ribs    8701     2282344
# 126693                                 Cheesy Bacon Bread  222001      689540
# 126694  Kittencal S Pan Seared Steak  Stove Top To Ove...  354979  2000242659
# 126695                               Montreal Steak Spice  415599      463435
#
#         rating  recipe_id
# ...

# %%
# tect
a = dfD3[dfD3.id == 533154] # есть отзыв
b = dfC[dfC.id == 35173] # нет отзыва
c = dfD3[dfD3.id == 3] # не включен в массив
print(a)
print(b)
print(c)
# Out:
#                         name      id     user_id  rating  recipe_id
# 79  Healthy Brownie In A Mug  533154  2002356287       0     533154
#                    name       id  user_id  rating
# 3  italian  gut busters  35173.0      NaN     NaN
# Empty DataFrame
# Columns: [name, id, user_id, rating, recipe_id]
# Index: []

# %% [markdown]
# 5.2 При помощи объединения таблиц и группировок, создайте `DataFrame`, состоящий из трех столбцов: `recipe_id`, `name`, `review_count`, где столбец `review_count` содержит кол-во отзывов, оставленных на рецепт `recipe_id`. У рецептов, на которые не оставлен ни один отзыв, в столбце `review_count` должен быть указан 0. Подтвердите правильность работы вашего кода, выбрав рецепт, не имеющий отзывов, и найдя строку, соответствующую этому рецепту, в полученном `DataFrame`.

# %%
new = pd.merge(recipes1[['name', 'id', 'description']], reviews1[['recipe_id']].dropna(), left_on='id', right_on='recipe_id', how='outer')
new = new.rename(columns={'description': 'review_count'})
new = new.drop('id', axis=1)
new_tab = pd.merge(new, new.groupby('recipe_id')['review_count'].count(), how='left', right_on='recipe_id', left_on='recipe_id')
new_tab = new_tab.drop('review_count_x', axis=1)
new_tab = new_tab.drop_duplicates('recipe_id')
new_tab = new_tab.rename(columns={'review_count_y':'review_count'})
new_tab
# Out:
#                                                 name  recipe_id  review_count
# 0              George S At The Cove  Black Bean Soup    44123.0           3.0
# 3                 Healthy For Them  Yogurt Popsicles    67664.0           8.0
# 11                      I Can T Believe It S Spinach    38798.0           3.0
# 14                              Italian  Gut Busters    35173.0           1.0
# 15          Love Is In The Air  Beef Fondue   Sauces    84797.0           8.0
# ...                                              ...        ...           ...
# 128577  Zurie S Holey Rustic Olive And Cheddar Bread   267661.0           4.0
# 128581          Zwetschgenkuchen  Bavarian Plum Cake   386977.0           2.0
# 128583   Zwiebelkuchen   Southwest German Onion Cake   103312.0           6.0
# 128589                                   Zydeco Soup   486161.0           6.0
# 128595        Cookies By Design   Cookies On A Stick   298512.0           1.0
#
# [28101 rows x 3 columns]

# %%
new_tab.loc[new_tab['review_count'] == 0].iloc[0]
# Out:
# name            5 Minute   White Chocolate Hazelnut Pie
# recipe_id                                       21629.0
# review_count                                        0.0
# Name: 1030, dtype: object

# %% [markdown]
# 5.3. Выясните, рецепты, добавленные в каком году, имеют наименьший средний рейтинг?

# %%
yeor_new = pd.merge(dfD3, reviews1[['recipe_id','date']].dropna(), left_on='id',right_on='recipe_id', how='outer')
yeor_new = yeor_new.drop_duplicates('name')
yeor_new = yeor_new.drop('recipe_id_x', axis=1)
yeor_new = yeor_new.drop('recipe_id_y', axis=1)
yeor_new = yeor_new.drop('user_id', axis=1)
yeor_new
# Out:
#                                                 name      id  rating  \
# 0                               Salmon With Tomatoes   57993       5
# 121                             Lemon Cajun Stir Fry  142201       5
# 265      Cottage Cheese  Honey And Cinnamon On Toast  252013       4
# 266                                    Belly Buttons  404716       5
# 387                               Double Tomato Soup  129396       5
# ...                                              ...     ...     ...
# 8421715                          Vegetable Pasta Pie   94096       5
# 8421716                         Crockery Pot Delight  368208       2
# 8421717             Apple Cider Cheesecake   No Cook  154964       5
# 8421718                     Winter Vegetable Lasagna  187418       5
# 8421719       G Nut Special Sauce And Sweet Potatoes  296868       4
#
#               date
# 0       2003-05-01
# 121     2007-09-16
# 265     2008-01-10
# 266     2017-12-11
# 387     2008-03-14
# ...

# %%
x = yeor_new.groupby(yeor_new['rating']).mean().min()
print(x)
yeor_new[yeor_new.id == 29444]
# Out:
# id    202592.29444
# dtype: float64
#                    name     id  rating       date
# 8099221  Easy Rum Slush  29444       5 2006-07-16

# %% [markdown]
# ### Сохранение таблиц `pd.DataFrame`

# %% [markdown]
# 6.1 Отсортируйте таблицу в порядке убывания величины столбца `name_word_count` и сохраните результаты выполнения заданий 3.1-3.3 в csv файл.

# %%
recipes_6 = recipes1.copy()
recipes_6.sort_values('name_word_count', ascending=False).head()
recipes_6.to_csv('/content/drive/MyDrive/L2/recipes_6.csv')

# %% [markdown]
# 6.2 Воспользовавшись `pd.ExcelWriter`, cохраните результаты 5.1 и 5.2 в файл: на лист с названием `Рецепты с оценками` сохраните результаты выполнения 5.1; на лист с названием `Количество отзывов по рецептам` сохраните результаты выполнения 5.2.

# %%
from csv import writer

with pd.ExcelWriter('/content/drive/MyDrive/L2/tab_5.xlsx') as writer:
  dfD3.to_excel(writer, sheet_name='Рецепты с оценками', index=True)
  new_tab.to_excel(writer, sheet_name='Количество отзывов по рецептам',index=True)
# Out:
# Exception ignored in: <function ZipFile.__del__ at 0x7aadf1b42320>
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/zipfile.py", line 1821, in __del__
#     self.close()
#   File "/usr/lib/python3.10/zipfile.py", line 1838, in close
#     self.fp.seek(self.start_dir)
# ValueError: seek of closed file

# %% [markdown]
# #### [версия 2]
# * Уточнены формулировки задач 1.1, 3.3, 4.2, 5.1, 5.2, 5.3
